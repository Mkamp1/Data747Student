# %% [markdown]
# ## Lab Assignment: Exporatory Data Analysis
#
# ### Objective: To gain an understanding of exploratory data analysis (EDA) techniques and their application using Pandas, Pandas Profiling, and Matplotlib.
#
# ### Instructions:
#
# 1. Load the iris using Pandas and display the first 5 rows.
# 2. Calculate the summary statistics of the dataset and display them.
# 3. Visualize the distribution of the target variable using a bar chart.
# 4. Visualize the distribution of the target variable by class using a stacked bar chart.
# 5. Plot a histogram to visualize the distribution.
# 6. Create a scatter plot to visualize the relationships.
# 7. Use Pandas profiling to generate a detailed report of the dataset.
# 8. Identify and visualize any missing values in the dataset.
# 9. Identify and visualize any outliers in the dataset.
# 10. Identify and visualize any correlations between variables in the dataset.
#
# ### Deliverables:
#
# 1. A Python file containing the four functions/programs.
# 2. A text file containing sample inputs and outputs for each function/program.
#
# ### Grading Criteria:
#
# 1. Correctness and functionality of each function/program
# 2. Proper use of basic control structures and functions
# 3. Code readability and organization
# 4. Note: Students are encouraged to work collaboratively, but each student must submit their own work. In addition, students should utilize version control (e.g. GitHub) to  manage their code and collaborate with peers.

# %% [markdown]
# Load the datset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import datasets as datasets
from ydata_profiling import ProfileReport

# Load the Iris dataset
iris = datasets.load_iris()

# Create a Pandas DataFrame from the dataset
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)

# Add the target variable to the DataFrame
df['target'] = iris.target

# %% [markdown]
# Display the first five rows of the dataset

# %%
print(df.head())
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %% [markdown]
# Display summary statistics

# %%
print(df.describe())
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)      target
# count        150.000000  150.000000
# mean           1.199333    1.000000
# std            0.762238    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000

# %% [markdown]
# Visualize the distribution of the target variable using a bar chart

# %%
target_counts = df['target'].value_counts()
plt.bar(target_counts.index, target_counts.values)
plt.xlabel('Target')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Visualize the distribution of the target variable by class using a stacked bar chart

# %%
sns.histplot(data=df, x='target', hue='target', multiple='stack')
# Out:
# <Axes: xlabel='target', ylabel='Count'>

# %% [markdown]
# Plot a histogram to visualize the distribution of sepal length

# %%
sns.histplot(data=df, x='sepal length (cm)')
# Out:
# <Axes: xlabel='sepal length (cm)', ylabel='Count'>

# %% [markdown]
# Create a scatter plot to visualize the relationship between sepal length and petal length

# %%
sns.scatterplot(data=df, x='sepal length (cm)', y='petal length (cm)', hue='target')
# Out:
# <Axes: xlabel='sepal length (cm)', ylabel='petal length (cm)'>

# %% [markdown]
# Use Pandas profiling to generate a detailed report of the dataset

# %%
profile = ProfileReport(df, title='Pandas Profiling Report', explorative=True)
profile.to_widgets()
# Out:
# ...
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# ...

# %% [markdown]
# Identify and visualize any missing data values in the dataset

# %%
sns.heatmap(df, cbar=False)
# Out:
# <Axes: >

# %% [markdown]
# Identify and visualize any correlations between variables in the dataset

# %%
sns.pairplot(data=df)
