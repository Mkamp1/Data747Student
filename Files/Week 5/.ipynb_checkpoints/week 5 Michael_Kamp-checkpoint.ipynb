# %% [markdown]
# ## Lab Assignment: Data Visualization with Matplotlib
# Student:     **Michael Kamp**
#
# ### Objective: To use Matplotlib to perform basic data visualizations.
#
# ### Instructions:
# In this lab assignment, you will explore data visualization using Python's Matplotlib library. You will use Matplotlib to create various visualizations based on provided datasets.
#
# 1. Create a line plot of the provided dataset with years on the x-axis and population on the y-axis.
# 2. Create a scatter plot of the provided dataset with horsepower on the x-axis and miles per gallon (mpg) on the y-axis.
# 3. Create a bar chart of the provided dataset with car brands on the x-axis and average price on the y-axis.
# 4. Create a histogram of the provided dataset with salaries on the x-axis and frequency on the y-axis.
# 5. Create a pie chart of the provided dataset with the percentage of car sales of each brand.
# 6. Create a stacked bar chart of the provided dataset with the years on the x-axis and the total number of medals won by each country on the y-axis. The stacked bars should show the number of gold, silver, and bronze medals won.
# 7. Create a box plot of the provided dataset with car prices grouped by brand.
# 8. Create a violin plot of the provided dataset with car prices grouped by brand.
# 9. Create a hexbin plot of the provided dataset with car prices on the x-axis and mileage on the y-axis.
# 10. Create a 3D scatter plot of the provided dataset with horsepower on the x-axis, weight on the y-axis, and miles per gallon on the z-axis.
#
# (Note: You can use sample datasets provided by Matplotlib or any other publicly available dataset for the above problems)
#
# ### Deliverable:
# Modify this notebook to include the python code as well as any documentation related to your submission.  Submit the notebook as your response in Blackboard.
#
# ### Grading Criteria:
#
# Your lab assignment will be graded based on the following criteria:
#
# - Correctness of the implementation
# - Proper use of basic control structures and functions
# - Code efficiency
# - Clarity and readability of the code
# - Compliance with the instructions and deliverables.
#
# ### Student Submission
# 1.  Create a line plot of the provided dataset with years on the x-axis and population on the y-axis.

# %% [markdown]
# 2. K-Nearest Neighbors
# - Load the Breast Cancer dataset from Scikit-Learn datasets.
# - Split the dataset into training and testing sets.
# - Implement a K-Nearest Neighbors classifier with k=5 and fit it to the training data.
# - Evaluate the performance of the K-Nearest Neighbors classifier on the testing data using precision, recall, and F1-score as the evaluation metrics.

# %% [markdown]
# 3. Create a bar chart of the provided dataset with car brands on the x-axis and average price on the y-axis.

# %% [markdown]
# 4. Create a histogram of the provided dataset with salaries on the x-axis and frequency on the y-axis.

# %% [markdown]
# 5. Create a pie chart of the provided dataset with the percentage of car sales of each brand.

# %% [markdown]
# 6. Create a stacked bar chart of the provided dataset with the years on the x-axis and the total number of medals won by each country on the y-axis. The stacked bars should show the number of gold, silver, and bronze medals won.

# %% [markdown]
# 7. Create a box plot of the provided dataset with car prices grouped by brand.

# %% [markdown]
# 8. Create a violin plot of the provided dataset with car prices grouped by brand.

# %% [markdown]
# 9. Create a hexbin plot of the provided dataset with car prices on the x-axis and mileage on the y-axis.

# %% [markdown]
# 10. Create a 3D scatter plot of the provided dataset with horsepower on the x-axis, weight on the y-axis, and miles per gallon on the z-axis.
